# %%
#Let's import all relevant libaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')
schema_df = pd.read_csv('survey_results_schema.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
# The three questions we want to asnwer

#1. Are there different approaches towards becoming a developer across the world?

#2. Do people with a non computer science degree have more problems getting into the field?

#3. Which skillset brings the most money?

# %%
df[df['Salary'].isnull() == False].shape[0]/

df.shape[0]
# Out:
# 0.25083670610211706

# %%
for col in df.columns:
    print(col)
# Out:
# Respondent
# Professional
# ProgramHobby
# Country
# University
# EmploymentStatus
# FormalEducation
# MajorUndergrad
# HomeRemote
# CompanySize
# CompanyType
# YearsProgram
# YearsCodedJob
# YearsCodedJobPast
# DeveloperType
# WebDeveloperType
# MobileDeveloperType
# NonDeveloperType
# CareerSatisfaction
# JobSatisfaction
# ExCoderReturn
# ExCoderNotForMe
# ExCoderBalance
# ExCoder10Years
# ExCoderBelonged
# ExCoderSkills
# ExCoderWillNotCode
# ExCoderActive
# PronounceGIF
# ProblemSolving
# BuildingThings
# LearningNewTech
# BoringDetails
# JobSecurity
# DiversityImportant
# AnnoyingUI
# FriendsDevelopers
# RightWrongWay
# UnderstandComputers
# SeriousWork
# InvestTimeTools
# WorkPayCare
# KinshipDevelopers
# ChallengeMyself
# CompetePeers
# ChangeWorld
# JobSeekingStatus
# HoursPerWeek
# LastNewJob
# AssessJobIndustry
# AssessJobRole
# AssessJobExp
# AssessJobDept
# AssessJobTech
# AssessJobProjects
# AssessJobCompensation
# AssessJobOffice
# AssessJobCommute
# AssessJobRemote
# ...
